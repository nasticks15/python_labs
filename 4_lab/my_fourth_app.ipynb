# %%
a = "змінна з текстом"
b = 1
b1 = 1.1
c = ["a", 1, 1.25, "Слово", a]
d = {"a": "Слово", "b": 1, a: b}
e = ("a", a)
f = {"ss", a + str(b)}

print(type(a), a)
print(type(b), b)
print(type(b1), b1)
print(type(c), c)
print(type(d), d)
print(type(e), e)
print(type(f), f)
# Out:
# <class 'str'> змінна з текстом
# <class 'int'> 1
# <class 'float'> 1.1
# <class 'list'> ['a', 1, 1.25, 'Слово', 'змінна з текстом']
# <class 'dict'> {'a': 'Слово', 'b': 1, 'змінна з текстом': 1}
# <class 'tuple'> ('a', 'змінна з текстом')
# <class 'set'> {'ss', 'змінна з текстом1'}

# %%
print("Перша константа: ", True)
print(f"Як можна так робити вивід? {True}")
import sys
help("keywords")
# Out:
# Перша константа:  True
# Як можна так робити вивід? True
#
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
print(abs(-12.5), f"є рівним {abs(12.5)}", "і якщо порівняти то: ", abs(-12.5) == abs(12.5))
# Out:
# 12.5 є рівним 12.5 і якщо порівняти то:  True

# %%
letters = ["a", "b", "c"]
for i in range(len(letters)):
    print(f"На позиції {i} знаходиться буква {letters[i]}")
else:
    print("Ця конструкція безглузда!")
# Out:
# На позиції 0 знаходиться буква a
# На позиції 1 знаходиться буква b
# На позиції 2 знаходиться буква c
# Ця конструкція безглузда!

# %%
from random import randint
A = randint(0, 1)
print(f"Значить А={A}" if A else "Але може бути що А={}".format(A))
# Out:
# Але може бути що А=0

# %%
A = 0
try:
    print("Що буде якщо", 10/A, "?")
except Exception as e:
    print("Невже це помилка > ", e)
finally:
    print("О це так на тобі!")
# Out:
# Невже це помилка >  division by zero
# О це так на тобі!

# %%
with open("README.md", "r") as f:
    for _, line in enumerate(f):
        print(f"{_})> ", line)

# %%
def a_b_func(a, b):
    return a, b

this_is_lambda = lambda first, age: f'Цей код написав: {first}, Мені {age:10d} років'
print("Це просто функція:", a_b_func, "\nА це лямбда:", this_is_lambda)
print("Це її виклик:", this_is_lambda('Богдан', 1_00_000))
print(this_is_lambda(*a_b_func("a", 1)))
# Out:
# Це просто функція: <function a_b_func at 0x0000028704FC2F20>
# А це лямбда: <function <lambda> at 0x0000028704FC2C00>
# Це її виклик: Цей код написав: Богдан, Мені     100000 років
# Цей код написав: a, Мені          1 років
