# %%
name = "AI"
print(f"Hello, I am {name}! Let's create something amazing together 🤖")
# Out:
# Hello, I am AI! Let's create something amazing together 🤖

# %% [markdown]
# 💻 Відповідь ChatGPT
# # Пояснення:
# Ця програма знайомить ШІ з людьми.
# Вона показує просту взаємодію — створення змінної та виведення повідомлення.
# Так починається спільна творчість людини й штучного інтелекту.

# %% [markdown]
# # Моя перша програма
# Програма виводить ім’я користувача, його улюблене місто та поточний час запуску.

# %%
from datetime import datetime
name = "Anastasiia"
location = "Lviv"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Anastasiia start programming at 2025-10-09 23:48:07.883038. Lviv is the best city!
